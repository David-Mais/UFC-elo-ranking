# %%
# UFC Fight Predictor
import pandas as pd
import numpy as np
import pickle
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

print("UFC FIGHT PREDICTION SYSTEM")
print("="*50)
# Out:
# UFC FIGHT PREDICTION SYSTEM
# ==================================================

# %%
# Some utility methods
import math
from numbers import Real

def _is_number(x):
    return isinstance(x, Real) and not (isinstance(x, float) and math.isnan(x))

def _both_numbers(*xs):
    return all(_is_number(x) for x in xs)

# %%
# Cell 1: Setup and Load Models
import pandas as pd
import numpy as np
import pickle
import os
from datetime import datetime

class UFCFightPredictor:
    def __init__(self):
        self.models = {}
        self.fighter_data = None
        self.load_fighter_data()
        self.load_models()
    
    def load_fighter_data(self):
        """Load current fighter profiles"""
        try:
            self.fighter_data = pd.read_csv("../build/fighter_profiles.csv")
            print(f"✓ Loaded {len(self.fighter_data)} fighter profiles")
        except FileNotFoundError:
            print("❌ fighter_profiles.csv not found!")
            return
    
    def load_models(self):
        """Load all trained models"""
        model_files = {
            'logistic': '../models/logistic_regression_model.pkl',
            'decision_tree': '../models/decision_tree_model.pkl', 
            'random_forest': '../models/random_forest_model.pkl',
            'xgboost': '../models/xgboost_model.pkl',
            'extratrees': '../models/extratrees_model.pkl',
            'lightgbm': '../models/lightgbm_model.pkl'
        }
        
        for name, filepath in model_files.items():
            try:
                with open(filepath, 'rb') as f:
                    self.models[name] = pickle.load(f)
                print(f"✓ Loaded {name} model")
            except FileNotFoundError:
                print(f"⚠️  {name} model not found")
    
    def find_fighter(self, name):
        """Find fighter by name with fuzzy matching"""
        name_lower = name.lower().strip()
        
        # Exact match
        exact = self.fighter_data[
            self.fighter_data['fighter_name'].str.lower() == name_lower
        ]
        if not exact.empty:
            return exact.iloc[0]
        
        # Partial match
        partial = self.fighter_data[
            self.fighter_data['fighter_name'].str.lower().str.contains(name_lower, na=False)
        ]
        
        if partial.empty:
            print(f"❌ Fighter '{name}' not found!")
            return None
        elif len(partial) > 1:
            print(f"Multiple matches for '{name}':")
            for _, fighter in partial.head(3).iterrows():
                print(f"  - {fighter['fighter_name']} (ELO: {fighter['current_elo_rating']:.0f})")
        
        return partial.iloc[0]
    
    def create_fight_features(self, fighter_a, fighter_b):
        def safe(v, default):
            return default if v is None or pd.isna(v) else v

        features = {}
        # Core
        features['current_elo_rating_A'] = safe(fighter_a.get('current_elo_rating'), 1500)
        features['current_elo_rating_B'] = safe(fighter_b.get('current_elo_rating'), 1500)
        features['current_elo_rating_diff'] = features['current_elo_rating_A'] - features['current_elo_rating_B']

        features['age_A'] = safe(fighter_a.get('age'), 30)
        features['age_B'] = safe(fighter_b.get('age'), 30)
        features['age_diff'] = features['age_A'] - features['age_B']

        features['reach_inches_A'] = safe(fighter_a.get('reach_inches'), 72)
        features['reach_inches_B'] = safe(fighter_b.get('reach_inches'), 72)
        features['reach_inches_diff'] = features['reach_inches_A'] - features['reach_inches_B']

        features['height_inches_A'] = safe(fighter_a.get('height_inches'), 70)
        features['height_inches_B'] = safe(fighter_b.get('height_inches'), 70)
        features['height_inches_diff'] = features['height_inches_A'] - features['height_inches_B']

        features['win_rate_A'] = safe(fighter_a.get('win_rate'), 0.5)
        features['win_rate_B'] = safe(fighter_b.get('win_rate'), 0.5)
        features['win_rate_diff'] = features['win_rate_A'] - features['win_rate_B']

        features['total_fights_A'] = safe(fighter_a.get('total_fights'), 0)
        features['total_fights_B'] = safe(fighter_b.get('total_fights'), 0)
        features['total_wins_A'] = safe(fighter_a.get('total_wins'), 0)
        features['total_wins_B'] = safe(fighter_b.get('total_wins'), 0)
        features['total_losses_A'] = safe(fighter_a.get('total_losses'), 0)
        features['total_losses_B'] = safe(fighter_b.get('total_losses'), 0)

        features['has_age_A'] = 1 if pd.notna(fighter_a.get('age')) else 0
        features['has_age_B'] = 1 if pd.notna(fighter_b.get('age')) else 0
        features['has_reach_A'] = 1 if pd.notna(fighter_a.get('reach_inches')) else 0
        features['has_reach_B'] = 1 if pd.notna(fighter_b.get('reach_inches')) else 0

        return features
        
    def predict_with_model(self, features, model_name):
        """Make prediction with specific model"""
        if model_name not in self.models:
            return None

        model_data = self.models[model_name]
        model = model_data['model']
        model_features = model_data['features']

        # Create feature vector in correct order, replace NaNs with 0
        feature_vector = []
        for feature in model_features:
            val = features.get(feature, 0)
            if pd.isna(val):
                val = 0
            feature_vector.append(val)

        X = np.array(feature_vector, dtype=float).reshape(1, -1)

        # Extra safety
        X = np.nan_to_num(X, nan=0.0)

        # Apply scaling if logistic regression
        if model_name == 'logistic' and 'scaler' in model_data and model_data['scaler']:
            X = model_data['scaler'].transform(X)

        # Get prediction
        prediction = model.predict(X)[0]
        try:
            prob_a_wins = model.predict_proba(X)[0][1]
        except:
            prob_a_wins = 0.7 if prediction == 1 else 0.3

        return {
            'prediction': prediction,
            'prob_a_wins': prob_a_wins,
            'prob_b_wins': 1 - prob_a_wins
        }
    
    def predict_fight(self, fighter_a_name, fighter_b_name):
        """Predict fight outcome using all available models (tolerant to NaNs/missing fields)."""
        print(f"\n{'='*60}")
        print(f"PREDICTING: {fighter_a_name} vs {fighter_b_name}")
        print(f"{'='*60}")
        
        # Find fighters
        fighter_a = self.find_fighter(fighter_a_name)
        fighter_b = self.find_fighter(fighter_b_name)
        if fighter_a is None or fighter_b is None:
            return None

        # Safe ELO print
        elo_a = fighter_a.get('current_elo_rating')
        elo_b = fighter_b.get('current_elo_rating')
        elo_a_str = f"{elo_a:.0f}" if _is_number(elo_a) else "N/A"
        elo_b_str = f"{elo_b:.0f}" if _is_number(elo_b) else "N/A"
        print(f"✓ {fighter_a.get('fighter_name', 'A')} (ELO: {elo_a_str})")
        print(f"✓ {fighter_b.get('fighter_name', 'B')} (ELO: {elo_b_str})")

        # Create features (may contain NaNs)
        features = self.create_fight_features(fighter_a, fighter_b)

        # Get predictions from all models (skip models returning NaNs/incomplete)
        predictions = {}
        for model_name in self.models:
            result = self.predict_with_model(features, model_name)
            if not result:
                continue
            pa = result.get('prob_a_wins')
            pb = result.get('prob_b_wins')
            pred_cls = result.get('prediction')
            if not (_both_numbers(pa, pb) and pred_cls in (0, 1)):
                # Skip unusable predictions
                continue
            predictions[model_name] = result

        # Display results
        print(f"\n📊 PREDICTIONS:")
        print("-" * 40)

        ensemble_prob = 0.0
        model_count = 0

        for model_name, pred in predictions.items():
            pa = pred['prob_a_wins']; pb = pred['prob_b_wins']
            winner = fighter_a['fighter_name'] if pred['prediction'] == 1 else fighter_b['fighter_name']
            confidence = max(pa, pb)

            print(f"{model_name.upper():15}: {winner}")
            print(f"{'':15}  Confidence: {confidence:.1%}")
            print(f"{'':15}  {fighter_a['fighter_name']}: {pa:.1%}")
            print(f"{'':15}  {fighter_b['fighter_name']}: {pb:.1%}")
            print()

            ensemble_prob += pa
            model_count += 1

        # Ensemble prediction
        if model_count > 0:
            ensemble_prob /= model_count
            ensemble_winner = fighter_a['fighter_name'] if ensemble_prob > 0.5 else fighter_b['fighter_name']
            ensemble_confidence = max(ensemble_prob, 1 - ensemble_prob)

            print("🏆 ENSEMBLE PREDICTION:")
            print(f"   Winner: {ensemble_winner}")
            print(f"   Confidence: {ensemble_confidence:.1%}")
            print(f"   {fighter_a['fighter_name']}: {ensemble_prob:.1%}")
            print(f"   {fighter_b['fighter_name']}: {(1 - ensemble_prob):.1%}")
        else:
            print("No valid model predictions available.")

        # Key factors — print ONLY when the required values are present (skip otherwise)
        print(f"\n🔍 KEY FACTORS:")

        elo_diff = features.get('current_elo_rating_diff')
        if _is_number(elo_diff):
            favored = fighter_a['fighter_name'] if elo_diff > 0 else fighter_b['fighter_name']
            print(f"   ELO Advantage: {elo_diff:+.0f} (favors {favored})")

        age_diff = features.get('age_diff')
        if _is_number(age_diff):
            print(f"   Age Difference: {age_diff:+.1f} years")

        reach_diff = features.get('reach_inches_diff')
        if _is_number(reach_diff):
            print(f"   Reach Advantage: {reach_diff:+.1f} inches")

        # Only compare win rate if BOTH are present
        win_a = fighter_a.get('win_rate')
        win_b = fighter_b.get('win_rate')
        if _both_numbers(win_a, win_b):
            print(f"   Win Rate: {win_a:.1%} vs {win_b:.1%}")

        return {
            'fighter_a': fighter_a.get('fighter_name'),
            'fighter_b': fighter_b.get('fighter_name'),
            'predictions': predictions,
            'ensemble_prob_a': (ensemble_prob if model_count > 0 else 0.5),
            'features': features
        }

# Initialize predictor
predictor = UFCFightPredictor()
# Out:
# ✓ Loaded 2624 fighter profiles
# ✓ Loaded logistic model
# ✓ Loaded decision_tree model
# ✓ Loaded random_forest model
# ✓ Loaded xgboost model
# ✓ Loaded extratrees model
# ✓ Loaded lightgbm model

# %%
# Quick ELO-based prediction for Roman Dolidze vs Anthony Hernandez
def quick_fight_prediction(fighter_a_name, fighter_b_name):
    print(f"\n{'='*60}")
    print(f"FIGHT PREDICTION: {fighter_a_name} vs {fighter_b_name}")
    print(f"{'='*60}")
    
    # Find fighters
    fighter_a = predictor.find_fighter(fighter_a_name)
    fighter_b = predictor.find_fighter(fighter_b_name)
    
    if fighter_a is None or fighter_b is None:
        return None
    
    print(f"✓ {fighter_a['fighter_name']} (ELO: {fighter_a['current_elo_rating']:.0f})")
    print(f"✓ {fighter_b['fighter_name']} (ELO: {fighter_b['current_elo_rating']:.0f})")
    
    # ELO-based win probability calculation
    elo_diff = fighter_a['current_elo_rating'] - fighter_b['current_elo_rating']
    prob_a_wins = 1 / (1 + 10**(-elo_diff/400))  # Standard ELO probability
    prob_b_wins = 1 - prob_a_wins
    
    winner = fighter_a['fighter_name'] if prob_a_wins > 0.5 else fighter_b['fighter_name']
    confidence = max(prob_a_wins, prob_b_wins)
    
    print(f"\n🥊 WIN PERCENTAGES:")
    print(f"   {fighter_a['fighter_name']}: {prob_a_wins:.1%}")
    print(f"   {fighter_b['fighter_name']}: {prob_b_wins:.1%}")
    print(f"\n🏆 PREDICTION: {winner} (Confidence: {confidence:.1%})")
    
    # Additional stats
    print(f"\n📊 FIGHTER COMPARISON:")
    print(f"   ELO Advantage: {abs(elo_diff):.0f} points (favors {fighter_a['fighter_name'] if elo_diff > 0 else fighter_b['fighter_name']})")
    print(f"   Fight Record: {fighter_a['total_wins']}-{fighter_a['total_losses']} vs {fighter_b['total_wins']}-{fighter_b['total_losses']}")
    print(f"   Win Rate: {fighter_a['win_rate']:.1%} vs {fighter_b['win_rate']:.1%}")
    
    age_a = fighter_a.get('age', 30) if pd.notna(fighter_a.get('age')) else 30
    age_b = fighter_b.get('age', 30) if pd.notna(fighter_b.get('age')) else 30
    print(f"   Age: {age_a:.0f} vs {age_b:.0f} years")
    
    reach_a = fighter_a.get('reach_inches', 72) if pd.notna(fighter_a.get('reach_inches')) else 72
    reach_b = fighter_b.get('reach_inches', 72) if pd.notna(fighter_b.get('reach_inches')) else 72
    print(f"   Reach: {reach_a:.0f}\" vs {reach_b:.0f}\"")
    
    return {
        'roman_dolidze_win_pct': prob_a_wins if fighter_a['fighter_name'].lower().find('dolidze') >= 0 else prob_b_wins,
        'anthony_hernandez_win_pct': prob_a_wins if fighter_a['fighter_name'].lower().find('hernandez') >= 0 else prob_b_wins,
        'prediction': winner,
        'confidence': confidence
    }

# Get the prediction
# Single call
result = quick_fight_prediction("Dricus Du Plessis", "Khamzat Chimaev")
# Out:
# ============================================================
# FIGHT PREDICTION: Dricus Du Plessis vs Khamzat Chimaev
# ============================================================
# ✓ Dricus Du Plessis (ELO: 1633)
# ✓ Khamzat Chimaev (ELO: 1586)
#
# 🥊 WIN PERCENTAGES:
#    Dricus Du Plessis: 56.6%
#    Khamzat Chimaev: 43.4%
#
# 🏆 PREDICTION: Dricus Du Plessis (Confidence: 56.6%)
#
# 📊 FIGHTER COMPARISON:
#    ELO Advantage: 46 points (favors Dricus Du Plessis)
#    Fight Record: 9-0 vs 6-0
#    Win Rate: 100.0% vs 100.0%
#    Age: 31 vs 31 years
#    Reach: 76" vs 75"

# %%
# Predict fights with all 3 models
# Try multiple fights to see how models compare
test_fights = [
    ("Roman Dolidze", "Anthony Hernandez"),              # Main Event
    ("Steve Erceg", "Ode Osbourne"),                    # Co-Main Event
    ("Iasmin Lucindo", "Angela Hill"),                  # Main Card
    ("Andre Fili", "Christian Rodriguez"),              # Main Card
    ("Miles Johns", "Jean Matsumoto"),                  # Main Card
    ("Eryk Anders", "Christian Leroy Duncan"),          # Main Card
    ("Julius Walker", "Raffael Cerqueira"),             # Prelim Card
    ("Elijah Smith", "Toshiomi Kazama"),               # Prelim Card
    ("Joselyne Edwards", "Priscila Cachoeira"),         # Prelim Card
    ("Uros Medic", "Gilbert Urbina"),                   # Prelim Card
    ("Gabriella Fernandes", "Julija Stoliarenko"),      # Prelim Card
    ("Cody Brundage", "Eric McConico")                  # Prelim Card
]


for fighter_a, fighter_b in test_fights:
    predictor.predict_fight(fighter_a, fighter_b)
    print("\n" + "="*40 + "\n")
# Out:
# ============================================================
# PREDICTING: Roman Dolidze vs Anthony Hernandez
# ============================================================
# ✓ Roman Dolidze (ELO: 1584)
# ✓ Anthony Hernandez (ELO: 1587)
#
# 📊 PREDICTIONS:
# ----------------------------------------
# LOGISTIC       : Anthony Hernandez
#                  Confidence: 94.9%
#                  Roman Dolidze: 5.1%
#                  Anthony Hernandez: 94.9%
#
# DECISION_TREE  : Anthony Hernandez
#                  Confidence: 65.5%
#                  Roman Dolidze: 34.5%
#                  Anthony Hernandez: 65.5%
#
# RANDOM_FOREST  : Anthony Hernandez
#                  Confidence: 52.2%
#                  Roman Dolidze: 47.8%
#                  Anthony Hernandez: 52.2%
#
# XGBOOST        : Roman Dolidze
#                  Confidence: 53.5%
#                  Roman Dolidze: 53.5%
#                  Anthony Hernandez: 46.5%
#
# EXTRATREES     : Anthony Hernandez
#                  Confidence: 51.8%
#                  Roman Dolidze: 48.2%
#                  Anthony Hernandez: 51.8%
#
# LIGHTGBM       : Roman Dolidze
#                  Confidence: 74.9%
#                  Roman Dolidze: 74.9%
#                  Anthony Hernandez: 25.1%
#
# 🏆 ENSEMBLE PREDICTION:
#    Winner: Anthony Hernandez
#    Confidence: 56.0%
#    Roman Dolidze: 44.0%
#    Anthony Hernandez: 56.0%
#
# 🔍 KEY FACTORS:
#    ELO Advantage: -4 (favors Anthony Hernandez)
#    Age Difference: +6.0 years
#    Reach Advantage: +1.0 inches
#    Win Rate: 75.0% vs 80.0%
#
# ========================================
#
#
# ============================================================
# PREDICTING: Steve Erceg vs Ode Osbourne
# ============================================================
# ✓ Steve Erceg (ELO: 1505)
# ✓ Ode Osbourne (ELO: 1484)
#
# 📊 PREDICTIONS:
# ----------------------------------------
# LOGISTIC       : Ode Osbourne
#                  Confidence: 90.3%
#                  Steve Erceg: 9.7%
#                  Ode Osbourne: 90.3%
#
# DECISION_TREE  : Steve Erceg
#                  Confidence: 71.1%
#                  Steve Erceg: 71.1%
#                  Ode Osbourne: 28.9%
#
# RANDOM_FOREST  : Steve Erceg
#                  Confidence: 68.8%
#                  Steve Erceg: 68.8%
#                  Ode Osbourne: 31.2%
#
# XGBOOST        : Steve Erceg
#                  Confidence: 75.1%
#                  Steve Erceg: 75.1%
#                  Ode Osbourne: 24.9%
#
# EXTRATREES     : Steve Erceg
#                  Confidence: 65.9%
#                  Steve Erceg: 65.9%
#                  Ode Osbourne: 34.1%
#
# LIGHTGBM       : Steve Erceg
#                  Confidence: 86.5%
#                  Steve Erceg: 86.5%
#                  Ode Osbourne: 13.5%
#
# 🏆 ENSEMBLE PREDICTION:
#    Winner:

#
# 🔍 KEY FACTORS:
#    ELO Advantage: +27 (favors Uros Medic)
#    Age Difference: +3.0 years
#    Reach Advantage: -4.0 inches
#    Win Rate: 57.1% vs 33.3%
#
# ========================================
#
#
# ============================================================
# PREDICTING: Gabriella Fernandes vs Julija Stoliarenko
# ============================================================
# ✓ Gabriella Fernandes (ELO: 1502)
# ✓ Julija Stoliarenko (ELO: 1460)
#
# 📊 PREDICTIONS:
# ----------------------------------------
# LOGISTIC       : Julija Stoliarenko
#                  Confidence: 62.8%
#                  Gabriella Fernandes: 37.2%
#                  Julija Stoliarenko: 62.8%
#
# DECISION_TREE  : Gabriella Fernandes
#                  Confidence: 84.9%
#                  Gabriella Fernandes: 84.9%
#                  Julija Stoliarenko: 15.1%
#
# RANDOM_FOREST  : Gabriella Fernandes
#                  Confidence: 81.1%
#                  Gabriella Fernandes: 81.1%
#                  Julija Stoliarenko: 18.9%
#
# XGBOOST        : Gabriella Fernandes
#                  Confidence: 88.8%
#                  Gabriella Fernandes: 88.8%
#                  Julija Stoliarenko: 11.2%
#
# EXTRATREES     : Gabriella Fernandes
#                  Confidence: 78.0%
#                  Gabriella Fernandes: 78.0%
#                  Julija Stoliarenko: 22.0%
#
# LIGHTGBM       : Gabriella Fernandes
#                  Confidence: 95.3%
#                  Gabriella Fernandes: 95.3%
#                  Julija Stoliarenko: 4.7%
#
# 🏆 ENSEMBLE PREDICTION:
#    Winner: Gabriella Fernandes
#    Confidence: 77.6%
#    Gabriella Fernandes: 77.6%
#    Julija Stoliarenko: 22.4%
#
# 🔍 KEY FACTORS:
#    ELO Advantage: +42 (favors Gabriella Fernandes)
#    Age Difference: -1.0 years
#    Reach Advantage: +6.0 inches
#    Win Rate: 50.0% vs 25.0%
#
# ========================================
#
#
# ============================================================
# PREDICTING: Cody Brundage vs Eric McConico
# ============================================================
# ✓ Cody Brundage (ELO: 1495)
# ✓ Eric McConico (ELO: 1486)
#
# 📊 PREDICTIONS:
# ----------------------------------------
# LOGISTIC       : Cody Brundage
#                  Confidence: 88.7%
#                  Cody Brundage: 88.7%
#                  Eric McConico: 11.3%
#
# DECISION_TREE  : Cody Brundage
#                  Confidence: 100.0%
#                  Cody Brundage: 100.0%
#                  Eric McConico: 0.0%
#
# RANDOM_FOREST  : Cody Brundage
#                  Confidence: 88.8%
#                  Cody Brundage: 88.8%
#                  Eric McConico: 11.2%
#
# XGBOOST        : Cody Brundage
#                  Confidence: 99.3%
#                  Cody Brundage: 99.3%
#                  Eric McConico: 0.7%
#
# EXTRATREES     : Cody Brundage
#                  Confidence: 96.2%
#                  Cody Brundage: 96.2%
#                  Eric McConico: 3.8%
#
# LIGHTGBM       : Cody Brundage
#                  Confidence: 99.8%
#                  Cody Brundage: 99.8%
#                  Eric McConico: 0.2%
#
# 🏆 ENSEMBLE PREDICTION:
#    Winner: Cody Brundage
#    Confidence: 95.5%
#    Cody Brundage: 95.5%
#    Eric McConico: 4.5%
#
# 🔍 KEY FACTORS:
#    ELO Advantage: +8 (favors Cody Brundage)
#    Age Difference: -4.0 years
#    Reach Advantage: +0.0 inches
#    Win Rate: 45.5% vs 0.0%
#
# ========================================

# %%
# Advanced Analysis for All Test Fights
import pandas as pd
import numpy as np

def advanced_fight_analysis(fighter_a, fighter_b):
    """Comprehensive analysis of a single fight"""
    print(f"\n{'='*80}")
    print(f"ADVANCED ANALYSIS: {fighter_a} vs {fighter_b}")
    print(f"{'='*80}")
    
    # Get prediction results
    result = predictor.predict_fight(fighter_a, fighter_b)
    
    if not result:
        print("❌ Could not analyze this fight (fighters not found)")
        return None
    
    # Extract data
    predictions = result.get('predictions', {})
    features = result.get('features', {})
    
    print(f"\n📊 MODEL CONSENSUS ANALYSIS:")
    print("-" * 50)
    
    if predictions:
        # Model predictions
        model_winners = []
        model_probs_a = []
        model_names = []
        
        for model_name, pred in predictions.items():
            winner = fighter_a if pred['prediction'] == 1 else fighter_b
            prob_a = pred['prob_a_wins']
            
            model_winners.append(winner)
            model_probs_a.append(prob_a)
            model_names.append(model_name.upper())
            
            print(f"{model_name.upper():15}: {winner:20} ({prob_a:.1%} vs {1-prob_a:.1%})")
        
        # Consensus metrics
        fighter_a_wins = sum(1 for winner in model_winners if winner == fighter_a)
        consensus_strength = max(fighter_a_wins, len(model_winners) - fighter_a_wins) / len(model_winners)
        prob_spread = max(model_probs_a) - min(model_probs_a)
        avg_prob_a = np.mean(model_probs_a)
        
        print(f"\n🎯 CONSENSUS METRICS:")
        print(f"   Models favoring {fighter_a}: {fighter_a_wins}/{len(model_winners)}")
        print(f"   Models favoring {fighter_b}: {len(model_winners) - fighter_a_wins}/{len(model_winners)}")
        print(f"   Consensus Strength: {consensus_strength:.1%}")
        print(f"   Probability Spread: {prob_spread:.1%}")
        print(f"   Average {fighter_a} win prob: {avg_prob_a:.1%}")
        
        # Consensus interpretation
        if consensus_strength >= 1.0:
            consensus_level = "UNANIMOUS"
        elif consensus_strength >= 0.67:
            consensus_level = "STRONG MAJORITY"
        else:
            consensus_level = "SPLIT DECISION"
        
        print(f"   Consensus Level: {consensus_level}")
    
    # Fighter comparison analysis
    if features:
        print(f"\n⚔️  FIGHTER ADVANTAGE BREAKDOWN:")
        print("-" * 50)
        
        # ELO Analysis
        elo_diff = features.get('current_elo_rating_diff', 0)
        elo_a = features.get('current_elo_rating_A', 1500)
        elo_b = features.get('current_elo_rating_B', 1500)
        elo_favorite = fighter_a if elo_diff > 0 else fighter_b
        
        print(f"📈 ELO RATINGS:")
        print(f"   {fighter_a}: {elo_a:.0f}")
        print(f"   {fighter_b}: {elo_b:.0f}")
        print(f"   Difference: {abs(elo_diff):.0f} points → {elo_favorite}")
        
        # Experience Analysis
        fights_a = features.get('total_fights_A', 0)
        fights_b = features.get('total_fights_B', 0)
        wins_a = features.get('total_wins_A', 0)
        wins_b = features.get('total_wins_B', 0)
        winrate_a = features.get('win_rate_A', 0)
        winrate_b = features.get('win_rate_B', 0)
        
        print(f"\n🥊 EXPERIENCE & RECORD:")
        print(f"   {fighter_a}: {wins_a}-{fights_a-wins_a} ({winrate_a:.1%})")
        print(f"   {fighter_b}: {wins_b}-{fights_b-wins_b} ({winrate_b:.1%})")
        
        exp_favorite = fighter_a if fights_a > fights_b else fighter_b
        record_favorite = fighter_a if winrate_a > winrate_b else fighter_b
        print(f"   Experience Edge: {exp_favorite} ({max(fights_a, fights_b)} vs {min(fights_a, fights_b)} fights)")
        print(f"   Win Rate Edge: {record_favorite}")
        
        # Physical Attributes
        age_diff = features.get('age_diff', 0)
        reach_diff = features.get('reach_inches_diff', 0)
        height_diff = features.get('height_inches_diff', 0)
        
        print(f"\n👤 PHYSICAL ADVANTAGES:")
        if abs(age_diff) > 1:
            age_advantage = fighter_a if age_diff < 0 else fighter_b
            print(f"   Age: {age_advantage} ({abs(age_diff):.1f} years younger)")
        else:
            print(f"   Age: Similar ages")
            
        if abs(reach_diff) > 1:
            reach_advantage = fighter_a if reach_diff > 0 else fighter_b
            print(f"   Reach: {reach_advantage} (+{abs(reach_diff):.1f} inches)")
        else:
            print(f"   Reach: Similar reach")
            
        if abs(height_diff) > 1:
            height_advantage = fighter_a if height_diff > 0 else fighter_b
            print(f"   Height: {height_advantage} (+{abs(height_diff):.1f} inches)")
        else:
            print(f"   Height: Similar height")
    
    # Risk Assessment
    print(f"\n⚠️  PREDICTION CONFIDENCE ASSESSMENT:")
    print("-" * 50)
    
    if predictions:
        if prob_spread < 0.1:
            confidence_level = "HIGH"
            risk_level = "LOW"
        elif prob_spread < 0.2:
            confidence_level = "MODERATE"
            risk_level = "MODERATE"
        else:
            confidence_level = "LOW"
            risk_level = "HIGH"
        
        print(f"   Prediction Confidence: {confidence_level}")
        print(f"   Betting Risk Level: {risk_level}")
        print(f"   Model Agreement: {prob_spread:.1%} spread")
        
        # Betting recommendation
        if consensus_strength >= 0.67 and prob_spread < 0.15:
            recommendation = "RECOMMENDED"
        elif consensus_strength >= 0.67:
            recommendation = "MODERATE CONFIDENCE"
        else:
            recommendation = "HIGH RISK - MODELS DISAGREE"
        
        print(f"   Betting Recommendation: {recommendation}")
    
    return {
        'consensus_strength': consensus_strength if predictions else 0,
        'prob_spread': prob_spread if predictions else 0,
        'avg_prob_a': avg_prob_a if predictions else 0.5,
        'elo_diff': elo_diff,
        'experience_diff': fights_a - fights_b if features else 0,
        'physical_advantages': {
            'age_diff': age_diff,
            'reach_diff': reach_diff,
            'height_diff': height_diff
        }
    }

print("🔬 COMPREHENSIVE FIGHT ANALYSIS REPORT")
print("="*80)

analysis_results = []

for fighter_a, fighter_b in test_fights:
    analysis = advanced_fight_analysis(fighter_a, fighter_b)
    if analysis:
        analysis['fight'] = f"{fighter_a} vs {fighter_b}"
        analysis_results.append(analysis)

# Summary comparison
print(f"\n\n📋 ANALYSIS SUMMARY COMPARISON")
print("="*80)

if analysis_results:
    print(f"{'FIGHT':<40} {'CONSENSUS':<12} {'SPREAD':<10} {'ELO DIFF':<10} {'CONFIDENCE'}")
    print("-" * 80)
    
    for result in analysis_results:
        fight = result['fight']
        consensus = f"{result['consensus_strength']:.1%}"
        spread = f"{result['prob_spread']:.1%}"
        elo_diff = f"{result['elo_diff']:+.0f}"
        
        if result['consensus_strength'] >= 0.67 and result['prob_spread'] < 0.15:
            confidence = "HIGH"
        elif result['consensus_strength'] >= 0.67:
            confidence = "MODERATE"
        else:
            confidence = "LOW"
        
        print(f"{fight:<40} {consensus:<12} {spread:<10} {elo_diff:<10} {confidence}")

print(f"\n💡 LEGEND:")
print(f"   CONSENSUS: % of models agreeing on winner")
print(f"   SPREAD: Difference between highest and lowest win probability")
print(f"   ELO DIFF: ELO rating difference (+ favors first fighter)")
print(f"   CONFIDENCE: Overall prediction reliability")
# Out:
# 🔬 COMPREHENSIVE FIGHT ANALYSIS REPORT
# ================================================================================
#
# ================================================================================
# ADVANCED ANALYSIS: Roman Dolidze vs Anthony Hernandez
# ================================================================================
#
# ============================================================
# PREDICTING: Roman Dolidze vs Anthony Hernandez
# ============================================================
# ✓ Roman Dolidze (ELO: 1584)
# ✓ Anthony Hernandez (ELO: 1587)
#
# 📊 PREDICTIONS:
# ----------------------------------------
# LOGISTIC       : Anthony Hernandez
#                  Confidence: 94.9%
#                  Roman Dolidze: 5.1%
#                  Anthony Hernandez: 94.9%
#
# DECISION_TREE  : Anthony Hernandez
#                  Confidence: 65.5%
#                  Roman Dolidze: 34.5%
#                  Anthony Hernandez: 65.5%
#
# RANDOM_FOREST  : Anthony Hernandez
#                  Confidence: 52.2%
#                  Roman Dolidze: 47.8%
#                  Anthony Hernandez: 52.2%
#
# XGBOOST        : Roman Dolidze
#                  Confidence: 53.5%
#                  Roman Dolidze: 53.5%
#                  Anthony Hernandez: 46.5%
#
# EXTRATREES     : Anthony Hernandez
#                  Confidence: 51.8%
#                  Roman Dolidze: 48.2%
#                  Anthony Hernandez: 51.8%
#
# LIGHTGBM       : Roman Dolidze
#                  Confidence: 74.9%
#                  Roman Dolidze: 74.9%
#                  Anthony Hernandez: 25.1%
#
# 🏆 ENSEMBLE PREDICTION:
#    Winner: Anthony Hernandez
#    Confidence: 56.0%
#    Roman Dolidze: 44.0%
#    Anthony Hernandez: 56.0%
#
# 🔍 KEY FACTORS:
#    ELO Advantage: -4 (favors Anthony Hernandez)
#    Age Difference: +6.0 years
#    Reach Advantage: +1.0 inches
#    Win Rate: 75.0% vs 80.0%
#
# 📊 MODEL CONSENSUS ANALYSIS:
# --------------------------------------------------
# LOGISTIC       : Anthony Hernandez    (5.1% vs 94.9%)
# DECISION_TREE  : Anthony Hernandez    (34.5% vs 65.5%)
# RANDOM_FOREST  : Anthony Hernandez    (47.8% vs 52.2%)
# XGBOOST        : Roman Dolidze        (53.5% vs 46.5%)
# EXTRATREES     : Anthony Hernandez    (48.2% vs 51.8%)
# LIGHTGBM       : Roman Dolidze        (74.9% vs 25.1%)
#
# 🎯 CONSENSUS METRICS:
#    Models favoring Roman Dolidze: 2/6
#    Models favoring Anthony Hernandez: 4/6
#    Consensus Strength: 66.7%
#    Probability Spread: 69.9%
#    Average Roman Dolidze win prob: 44.0%
#    Consensus Level: SPLIT DECISION
#
# ⚔️  FIGHTER ADVANTAGE BREAKDOWN:
# --------------------------------------------------
# 📈 ELO RATINGS:
#    Roman Dolidze: 1584
#    Anthony Hernandez: 1587
#    Difference: 4 points → Anthony Hernandez
#
# 🥊 EXPERIENCE & RECORD:
#    Roman Dolidze: 9-3 (75.0%)
#    Anthony Hernandez: 8-2 (80.0%)
#    Experience Edge: Roman Dolidze (12 vs 10 fights)
#    Win Rate Edge: Anthony Hernandez
#
# 👤 PHYSICAL ADVANTAGES:
#    Age: Anthony Hernandez (6.0 years younger)
#    Reach: Similar reach
#    Height: Roman Dolidze (+2.0 inches)
#
# ⚠️  PREDICTION CONFIDENCE ASSESSMENT:
# --------------------------------------------------
#    Prediction Confidence: LOW
#    Betting Risk Level: HIGH
#    Model Agreement: 69.9% spread
#    Betting Recommendation: HIGH RISK - MODELS DISAGREE
#
# ================================================================================
# ADVANCED ANALYSIS: Steve Erceg vs Ode Osbourne
# ================================================================================
#
# ============================================================
# PREDICTING: Steve Erceg vs Ode Osbourne
# ============================================================
# ✓ Steve Erceg (ELO: 1505)
# ✓ Ode Osbourne (ELO: 1484)
#
# 📊 PREDICTIONS:
# ----------------------------------------
# LOGISTIC       : Ode Osbourne
#                  Confidence: 90.3%
#                  Steve Erceg: 9.7%
#                  Ode Osbourne: 90.3%
#
# DECISION_TREE  : Steve Erceg
#                  Confidence: 71.1%
#                  Steve Erceg: 71.1%
#                  Ode Osbourne: 28.9%
#
# RANDOM_FOREST  : Steve Erceg
#                  Confidence: 68.8%
#                  Steve Erceg: 68.8%
#                  Ode Osbourne: 31.2%
#
# XGBOOST        : Steve Erceg
#                  Confidence: 75.1%
#                  Steve Erceg: 75.1%
#                  Ode Osbourne: 24.9%
#
# EXTRATREES     : Steve Erceg
#                  Confidence: 65.9%
#                  Steve Erceg: 65.9%
#                  Ode Osbourne: 34.1%
#
# LIGHTGBM       : Steve Erceg
#                  Confidence: 86.5%
#                  Steve Erceg: 86.5%
#                  Ode Osbourne: 13.5%
#
# 🏆 ENSEMBLE PREDICTION:
#    Winner: Steve Erceg
#    Confidence: 62.9%
#    Steve Erceg: 62.9%
#    Ode Osbourne: 37.1%
#
# 🔍 KEY FACTORS:
#    ELO Advantage: +21 (favors Steve Erceg)
#    Age Difference: -3.0 years
#    Reach Advantage: -1.0 inches
#    Win Rate: 50.0% vs 45.5%
#
# 📊 MODEL CONSENSUS ANALYSIS:
# --------------------------------------------------
# LOGISTIC       : Ode Osbourne         (9.7% vs 90.3%)
# DECISION_TREE  : Steve Erceg          (71.1% vs 28.9%)
# RANDOM_FOREST  : Steve Erceg          (68.8% vs 31.2%)
# XGBOOST        : Steve Erceg          (75.1% vs 24.9%)
# EXTRATREES     : Steve Erceg          (65.9% vs 34.1%)
# LIGHTGBM       : Steve Erceg          (86.5% vs 13.5%)
#
# 🎯 CONSENSUS METRICS:
#    Models favoring Steve Erceg: 5/6
#    Models favoring Ode Osbourne: 1/6
#    Consensus Strength: 83.3%
#    Probability Spread: 76.8%
#    Average Steve Erceg win prob: 62.9%
#    Consensus Level: STRONG MAJORITY
#
# ⚔️  FIGHTER ADVANTAGE BREAKDOWN:
# --------------------------------------------------
# 📈 ELO RATINGS:
#    Steve Erceg: 1505
#    Ode Osbourne: 1484
#    Difference: 21 points → Steve Erceg
#
# 🥊 EXPERIENCE & RECORD:
#    Steve Erceg: 3-3 (50.0%)
#    Ode Osbourne: 5-6 (45.5%)
#    Experience Edge: Ode Osbourne (11 vs 6 fights)
#    Win Rate Edge: Steve Erceg
#
# 👤 PHYSICAL ADVANTAGES:
#    Age: Steve Erceg (3.0 years younger)
#    Reach: Similar reach
#    Height: Steve Erceg (+3.0 inches)
#
# ⚠️  PREDICTION CONFIDENCE ASSESSMENT:
# --------------------------------------------------
#    Prediction Confidence: LOW
#    Betting Risk Level: HIGH
#    Model Agreement: 76.8% spread
#    Betting Recommendation: MODERATE CONFIDENCE
#
# ================================================================================
# ADVANCED ANALYSIS: Iasmin Lucindo vs Angela Hill
# ================================================================================
#
# ============================================================
# PREDICTING: Iasmin Lucindo vs Angela Hill
# ============================================================
# ✓ Iasmin Lucindo (ELO: 1529)
# ✓ Angela Hill (ELO: 1518)
#
# 📊 PREDICTIONS:
# ----------------------------------------
# LOGISTIC       : Angela Hill
#                  Confidence: 86.5%
#                  Iasmin Lucindo: 13.5%
#                  Angela Hill: 86.5%
#
# DECISION_TREE  : Iasmin Lucindo
#                  Confidence: 60.1%
#                  Iasmin Lucindo: 60.1%
#                  Angela Hill: 39.9%
#
# RANDOM_FOREST  : Iasmin Lucindo
#                  Confidence: 67.0%
#                  Iasmin Lucindo: 67.0%
#                  Angela Hill: 33.0%

#
# 🔍 KEY FACTORS:
#    ELO Advantage: -14 (favors Christian Rodriguez)
#    Age Difference: +8.0 years
#    Reach Advantage: +3.0 inches
#    Win Rate: 52.2% vs 62.5%
#
# 📊 MODEL CONSENSUS ANALYSIS:
# --------------------------------------------------
# LOGISTIC       : Christian Rodriguez  (3.5% vs 96.5%)
# DECISION_TREE  : Christian Rodriguez  (34.5% vs 65.5%)
# RANDOM_FOREST  : Christian Rodriguez  (45.0% vs 55.0%)
# XGBOOST        : Andre Fili           (50.8% vs 49.2%)
# EXTRATREES     : Christian Rodriguez  (43.6% vs 56.4%)
# LIGHTGBM       : Andre Fili           (73.2% vs 26.8%)
#
# 🎯 CONSENSUS METRICS:
#    Models favoring Andre Fili: 2/6
#    Models favoring Christian Rodriguez: 4/6
#    Consensus Strength: 66.7%
#    Probability Spread: 69.8%
#    Average Andre Fili win prob: 41.8%
#    Consensus Level: SPLIT DECISION
#
# ⚔️  FIGHTER ADVANTAGE BREAKDOWN:
# --------------------------------------------------
# 📈 ELO RATINGS:
#    Andre Fili: 1509
#    Christian Rodriguez: 1523
#    Difference: 14 points → Christian Rodriguez
#
# 🥊 EXPERIENCE & RECORD:
#    Andre Fili: 12-11 (52.2%)
#    Christian Rodriguez: 5-3 (62.5%)
#    Experience Edge: Andre Fili (23 vs 8 fights)
#    Win Rate Edge: Christian Rodriguez
#
# 👤 PHYSICAL ADVANTAGES:
#    Age: Christian Rodriguez (8.0 years younger)
#    Reach: Andre Fili (+3.0 inches)
#    Height: Andre Fili (+4.0 inches)
#
# ⚠️  PREDICTION CONFIDENCE ASSESSMENT:
# --------------------------------------------------
#    Prediction Confidence: LOW
#    Betting Risk Level: HIGH
#    Model Agreement: 69.8% spread
#    Betting Recommendation: HIGH RISK - MODELS DISAGREE
#
# ================================================================================
# ADVANCED ANALYSIS: Miles Johns vs Jean Matsumoto
# ================================================================================
#
# ============================================================
# PREDICTING: Miles Johns vs Jean Matsumoto
# ============================================================
# ✓ Miles Johns (ELO: 1542)
# ✓ Jean Matsumoto (ELO: 1515)
#
# 📊 PREDICTIONS:
# ----------------------------------------
# LOGISTIC       : Jean Matsumoto
#                  Confidence: 81.4%
#                  Miles Johns: 18.6%
#                  Jean Matsumoto: 81.4%
#
# DECISION_TREE  : Miles Johns
#                  Confidence: 71.1%
#                  Miles Johns: 71.1%
#                  Jean Matsumoto: 28.9%
#
# RANDOM_FOREST  : Miles Johns
#                  Confidence: 68.2%
#                  Miles Johns: 68.2%
#                  Jean Matsumoto: 31.8%
#
# XGBOOST        : Miles Johns
#                  Confidence: 77.3%
#                  Miles Johns: 77.3%
#                  Jean Matsumoto: 22.7%
#
# EXTRATREES     : Miles Johns
#                  Confidence: 66.2%
#                  Miles Johns: 66.2%
#                  Jean Matsumoto: 33.8%
#
# LIGHTGBM       : Miles Johns
#                  Confidence: 89.0%
#                  Miles Johns: 89.0%
#                  Jean Matsumoto: 11.0%
#
# 🏆 ENSEMBLE PREDICTION:
#    Winner: Miles Johns
#    Confidence: 65.1%
#    Miles Johns: 65.1%
#    Jean Matsumoto: 34.9%
#
# 🔍 KEY FACTORS:
#    ELO Advantage: +27 (favors Miles Johns)
#    Age Difference: +6.0 years
#    Reach Advantage: -6.0 inches
#    Win Rate: 70.0% vs 66.7%
#
# 📊 MODEL CONSENSUS ANALYSIS:
# --------------------------------------------------
# LOGISTIC       : Jean Matsumoto       (18.6% vs 81.4%)
# DECISION_TREE  : Miles Johns          (71.1% vs 28.9%)
# RANDOM_FOREST  : Miles Johns          (68.2% vs 31.8%)
# XGBOOST        : Miles Johns          (77.3% vs 22.7%)
# EXTRATREES     : Miles Johns          (66.2% vs 33.8%)
# LIGHTGBM       : Miles Johns          (89.0% vs 11.0%)
#
# 🎯 CONSENSUS METRICS:
#    Models favoring Miles Johns: 5/6
#    Models favoring Jean Matsumoto: 1/6
#    Consensus Strength: 83.3%
#    Probability Spread: 70.4%
#    Average Miles Johns win prob: 65.1%
#    Consensus Level: STRONG MAJORITY
#
# ⚔️  FIGHTER ADVANTAGE BREAKDOWN:
# --------------------------------------------------
# 📈 ELO RATINGS:
#    Miles Johns: 1542
#    Jean Matsumoto: 1515
#    Difference: 27 points → Miles Johns
#
# 🥊 EXPERIENCE & RECORD:
#    Miles Johns: 7-3 (70.0%)
#    Jean Matsumoto: 2-1 (66.7%)
#    Experience Edge: Miles Johns (10 vs 3 fights)
#    Win Rate Edge: Miles Johns
#
# 👤 PHYSICAL ADVANTAGES:
#    Age: Jean Matsumoto (6.0 years younger)
#    Reach: Jean Matsumoto (+6.0 inches)
#    Height: Jean Matsumoto (+3.0 inches)
#
# ⚠️  PREDICTION CONFIDENCE ASSESSMENT:
# --------------------------------------------------
#    Prediction Confidence: LOW
#    Betting Risk Level: HIGH
#    Model Agreement: 70.4% spread
#    Betting Recommendation: MODERATE CONFIDENCE
#
# ================================================================================
# ADVANCED ANALYSIS: Eryk Anders vs Christian Leroy Duncan
# ================================================================================
#
# ============================================================
# PREDICTING: Eryk Anders vs Christian Leroy Duncan
# ============================================================
# ✓ Eryk Anders (ELO: 1525)
# ✓ Christian Leroy Duncan (ELO: 1516)
#
# 📊 PREDICTIONS:
# ----------------------------------------
# LOGISTIC       : Christian Leroy Duncan
#                  Confidence: 77.1%
#                  Eryk Anders: 22.9%
#                  Christian Leroy Duncan: 77.1%
#
# DECISION_TREE  : Eryk Anders
#                  Confidence: 53.4%
#                  Eryk Anders: 53.4%
#                  Christian Leroy Duncan: 46.6%
#
# RANDOM_FOREST  : Eryk Anders
#                  Confidence: 61.3%
#                  Eryk Anders: 61.3%
#                  Christian Leroy Duncan: 38.7%
#
# XGBOOST        : Eryk Anders
#                  Confidence: 68.8%
#                  Eryk Anders: 68.8%
#                  Christian Leroy Duncan: 31.2%
#
# EXTRATREES     : Eryk Anders
#                  Confidence: 54.1%
#                  Eryk Anders: 54.1%
#                  Christian Leroy Duncan: 45.9%
#
# LIGHTGBM       : Eryk Anders
#                  Confidence: 82.1%
#                  Eryk Anders: 82.1%
#                  Christian Leroy Duncan: 17.9%
#
# 🏆 ENSEMBLE PREDICTION:
#    Winner: Eryk Anders
#    Confidence: 57.1%
#    Eryk Anders: 57.1%
#    Christian Leroy Duncan: 42.9%
#
# 🔍 KEY FACTORS:
#    ELO Advantage: +8 (favors Eryk Anders)
#    Age Difference: +8.0 years
#    Reach Advantage: +3.0 inches
#    Win Rate: 52.9% vs 60.0%
#
# 📊 MODEL CONSENSUS ANALYSIS:
# --------------------------------------------------
# LOGISTIC       : Christian Leroy Duncan (22.9% vs 77.1%)
# DECISION_TREE  : Eryk Anders          (53.4% vs 46.6%)
# RANDOM_FOREST  : Eryk Anders          (61.3% vs 38.7%)
# XGBOOST        : Eryk Anders          (68.8% vs 31.2%)
# EXTRATREES     : Eryk Anders          (54.1% vs 45.9%)
# LIGHTGBM       : Eryk Anders          (82.1% vs 17.9%)
#
# 🎯 CONSENSUS METRICS:
#    Models favoring Eryk Anders: 5/6
#    Models favoring Christian Leroy Duncan: 1/6
#    Consensus Strength: 83.3%
#    Probability Spread: 59.2%
#    Average Eryk Anders win prob: 57.1%
#    Consensus Level: STRONG MAJORITY
#
# ⚔️  FIGHTER ADVANTAGE BREAKDOWN:
# --------------------------------------------------
# 📈 ELO RATINGS:
#    Eryk Anders: 1525
#    Christian Leroy Duncan: 1516
#    Difference: 8 points → Eryk Anders
#
# 🥊 EXPERIENCE & RECORD:
#    Eryk Anders: 9-8 (52.9%)
#    Christian Leroy Duncan: 3-2 (60.0%)
#    Experience Edge: Eryk Anders (17 vs 5 fights)
#    Win Rate Edge: Christian Leroy Duncan
#
# 👤 PHYSICAL ADVANTAGES:
#    Age: Christian Leroy Duncan (8.0 years younger)
#    Reach: Eryk Anders (+3.0 inches)
#    Height: Eryk Anders (+3.0 inches)
#
# ⚠️  PREDICTION CONFIDENCE ASSESSMENT:
# --------------------------------------------------
#    Prediction Confidence: LOW
#    Betting Risk Level: HIGH
#    Model Agreement: 59.2% spread
#    Betting Recommendation: MODERATE CONFIDENCE
#
# ================================================================================
# ADVANCED ANALYSIS: Julius Walker vs Raffael Cerqueira
# ================================================================================
#
# ============================================================
# PREDICTING: Julius Walker vs Raffael Cerqueira
# ============================================================
# ❌ Fighter 'Raffael Cerqueira' not found!
# ❌ Could not analyze this fight (fighters not found)
#
# ================================================================================
# ADVANCED ANALYSIS: Elijah Smith vs Toshiomi Kazama
# ================================================================================
#
# ============================================================
# PREDICTING: Elijah Smith vs Toshiomi Kazama
# ============================================================
# ✓ Elijah Smith (ELO: 1511)
# ✓ Toshiomi Kazama (ELO: 1500)
#
# 📊 PREDICTIONS:
# ----------------------------------------
# LOGISTIC       : Elijah Smith
#                  Confidence: 81.1%
#                  Elijah Smith: 81.1%
#                  Toshiomi Kazama: 18.9%
#
# DECISION_TREE  : Elijah Smith
#                  Confidence: 100.0%
#                  Elijah Smith: 100.0%
#                  Toshiomi Kazama: 0.0%
#
# RANDOM_FOREST  : Elijah Smith
#                  Confidence: 86.2%
#                  Elijah Smith: 86.2%
#                  Toshiomi Kazama: 13.8%
#
# XGBOOST        : Elijah Smith
#                  Confidence: 96.7%
#                  Elijah Smith: 96.7%
#                  Toshiomi Kazama: 3.3%
#
# EXTRATREES     : Elijah Smith
#                  Confidence: 86.5%
#                  Elijah Smith: 86.5%
#                  Toshiomi Kazama: 13.5%
#
# LIGHTGBM       : Elijah Smith
#                  Confidence: 99.2%
#                  Elijah Smith: 99.2%
#                  Toshiomi Kazama: 0.8%
#
# 🏆 ENSEMBLE PREDICTION:
#    Winner: Elijah Smith
#    Confidence: 91.6%
#    Elijah Smith: 91.6%
#    Toshiomi Kazama: 8.4%
#
# 🔍 KEY FACTORS:
#    ELO Advantage: +11 (favors Elijah Smith)
#    Age Difference: +2.0 years
#    Reach Advantage: +0.0 inches
#    Win Rate: 100.0% vs 50.0%
#
# 📊 MODEL CONSENSUS ANALYSIS:
# --------------------------------------------------
# LOGISTIC       : Elijah Smith         (81.1% vs 18.9%)
# DECISION_TREE  : Elijah Smith         (100.0% vs 0.0%)
# RANDOM_FOREST  : Elijah Smith         (86.2% vs 13.8%)
# XGBOOST        : Elijah Smith         (96.7% vs 3.3%)
# EXTRATREES     : Elijah Smith         (86.5% vs 13.5%)
# LIGHTGBM       : Elijah Smith         (99.2% vs 0.8%)
#
# 🎯 CONSENSUS METRICS:
#    Models favoring Elijah Smith: 6/6
#    Models favoring Toshiomi Kazama: 0/6
#    Consensus Strength: 100.0%
#    Probability Spread: 18.9%
#    Average Elijah Smith win prob: 91.6%
#    Consensus Level: UNANIMOUS
#
# ⚔️  FIGHTER ADVANTAGE BREAKDOWN:
# --------------------------------------------------
# 📈 ELO RATINGS:
#    Elijah Smith: 1511
#    Toshiomi Kazama: 1500
#    Difference: 11 points → Elijah Smith
#
# 🥊 EXPERIENCE & RECORD:
#    Elijah Smith: 1-0 (100.0%)
#    Toshiomi Kazama: 1-1 (50.0%)
#    Experience Edge: Toshiomi Kazama (2 vs 1 fights)
#    Win Rate Edge: Elijah Smith
#
# 👤 PHYSICAL ADVANTAGES:
#    Age: Toshiomi Kazama (2.0 years younger)
#    Reach: Similar reach
#    Height: Similar height
#
# ⚠️  PREDICTION CONFIDENCE ASSESSMENT:
# --------------------------------------------------
#    Prediction Confidence

#
# 🏆 ENSEMBLE PREDICTION:
#    Winner: Gabriella Fernandes
#    Confidence: 77.6%
#    Gabriella Fernandes: 77.6%
#    Julija Stoliarenko: 22.4%
#
# 🔍 KEY FACTORS:
#    ELO Advantage: +42 (favors Gabriella Fernandes)
#    Age Difference: -1.0 years
#    Reach Advantage: +6.0 inches
#    Win Rate: 50.0% vs 25.0%
#
# 📊 MODEL CONSENSUS ANALYSIS:
# --------------------------------------------------
# LOGISTIC       : Julija Stoliarenko   (37.2% vs 62.8%)
# DECISION_TREE  : Gabriella Fernandes  (84.9% vs 15.1%)
# RANDOM_FOREST  : Gabriella Fernandes  (81.1% vs 18.9%)
# XGBOOST        : Gabriella Fernandes  (88.8% vs 11.2%)
# EXTRATREES     : Gabriella Fernandes  (78.0% vs 22.0%)
# LIGHTGBM       : Gabriella Fernandes  (95.3% vs 4.7%)
#
# 🎯 CONSENSUS METRICS:
#    Models favoring Gabriella Fernandes: 5/6
#    Models favoring Julija Stoliarenko: 1/6
#    Consensus Strength: 83.3%
#    Probability Spread: 58.2%
#    Average Gabriella Fernandes win prob: 77.6%
#    Consensus Level: STRONG MAJORITY
#
# ⚔️  FIGHTER ADVANTAGE BREAKDOWN:
# --------------------------------------------------
# 📈 ELO RATINGS:
#    Gabriella Fernandes: 1502
#    Julija Stoliarenko: 1460
#    Difference: 42 points → Gabriella Fernandes
#
# 🥊 EXPERIENCE & RECORD:
#    Gabriella Fernandes: 2-2 (50.0%)
#    Julija Stoliarenko: 2-6 (25.0%)
#    Experience Edge: Julija Stoliarenko (8 vs 4 fights)
#    Win Rate Edge: Gabriella Fernandes
#
# 👤 PHYSICAL ADVANTAGES:
#    Age: Similar ages
#    Reach: Gabriella Fernandes (+6.0 inches)
#    Height: Similar height
#
# ⚠️  PREDICTION CONFIDENCE ASSESSMENT:
# --------------------------------------------------
#    Prediction Confidence: LOW
#    Betting Risk Level: HIGH
#    Model Agreement: 58.2% spread
#    Betting Recommendation: MODERATE CONFIDENCE
#
# ================================================================================
# ADVANCED ANALYSIS: Cody Brundage vs Eric McConico
# ================================================================================
#
# ============================================================
# PREDICTING: Cody Brundage vs Eric McConico
# ============================================================
# ✓ Cody Brundage (ELO: 1495)
# ✓ Eric McConico (ELO: 1486)
#
# 📊 PREDICTIONS:
# ----------------------------------------
# LOGISTIC       : Cody Brundage
#                  Confidence: 88.7%
#                  Cody Brundage: 88.7%
#                  Eric McConico: 11.3%
#
# DECISION_TREE  : Cody Brundage
#                  Confidence: 100.0%
#                  Cody Brundage: 100.0%
#                  Eric McConico: 0.0%
#
# RANDOM_FOREST  : Cody Brundage
#                  Confidence: 88.8%
#                  Cody Brundage: 88.8%
#                  Eric McConico: 11.2%
#
# XGBOOST        : Cody Brundage
#                  Confidence: 99.3%
#                  Cody Brundage: 99.3%
#                  Eric McConico: 0.7%
#
# EXTRATREES     : Cody Brundage
#                  Confidence: 96.2%
#                  Cody Brundage: 96.2%
#                  Eric McConico: 3.8%
#
# LIGHTGBM       : Cody Brundage
#                  Confidence: 99.8%
#                  Cody Brundage: 99.8%
#                  Eric McConico: 0.2%
#
# 🏆 ENSEMBLE PREDICTION:
#    Winner: Cody Brundage
#    Confidence: 95.5%
#    Cody Brundage: 95.5%
#    Eric McConico: 4.5%
#
# 🔍 KEY FACTORS:
#    ELO Advantage: +8 (favors Cody Brundage)
#    Age Difference: -4.0 years
#    Reach Advantage: +0.0 inches
#    Win Rate: 45.5% vs 0.0%
#
# 📊 MODEL CONSENSUS ANALYSIS:
# --------------------------------------------------
# LOGISTIC       : Cody Brundage        (88.7% vs 11.3%)
# DECISION_TREE  : Cody Brundage        (100.0% vs 0.0%)
# RANDOM_FOREST  : Cody Brundage        (88.8% vs 11.2%)
# XGBOOST        : Cody Brundage        (99.3% vs 0.7%)
# EXTRATREES     : Cody Brundage        (96.2% vs 3.8%)
# LIGHTGBM       : Cody Brundage        (99.8% vs 0.2%)
#
# 🎯 CONSENSUS METRICS:
#    Models favoring Cody Brundage: 6/6
#    Models favoring Eric McConico: 0/6
#    Consensus Strength: 100.0%
#    Probability Spread: 11.3%
#    Average Cody Brundage win prob: 95.5%
#    Consensus Level: UNANIMOUS
#
# ⚔️  FIGHTER ADVANTAGE BREAKDOWN:
# --------------------------------------------------
# 📈 ELO RATINGS:
#    Cody Brundage: 1495
#    Eric McConico: 1486
#    Difference: 8 points → Cody Brundage
#
# 🥊 EXPERIENCE & RECORD:
#    Cody Brundage: 5-6 (45.5%)
#    Eric McConico: 0-1 (0.0%)
#    Experience Edge: Cody Brundage (11 vs 1 fights)
#    Win Rate Edge: Cody Brundage
#
# 👤 PHYSICAL ADVANTAGES:
#    Age: Cody Brundage (4.0 years younger)
#    Reach: Similar reach
#    Height: Cody Brundage (+2.0 inches)
#
# ⚠️  PREDICTION CONFIDENCE ASSESSMENT:
# --------------------------------------------------
#    Prediction Confidence: MODERATE
#    Betting Risk Level: MODERATE
#    Model Agreement: 11.3% spread
#    Betting Recommendation: RECOMMENDED
#
#
# 📋 ANALYSIS SUMMARY COMPARISON
# ================================================================================
# FIGHT                                    CONSENSUS    SPREAD     ELO DIFF   CONFIDENCE
# --------------------------------------------------------------------------------
# Roman Dolidze vs Anthony Hernandez       66.7%        69.9%      -4         LOW
# Steve Erceg vs Ode Osbourne              83.3%        76.8%      +21        MODERATE
# Iasmin Lucindo vs Angela Hill            83.3%        76.2%      +11        MODERATE
# Andre Fili vs Christian Rodriguez        66.7%        69.8%      -14        LOW
# Miles Johns vs Jean Matsumoto            83.3%        70.4%      +27        MODERATE
# Eryk Anders vs Christian Leroy Duncan    83.3%        59.2%      +8         MODERATE
# Elijah Smith vs Toshiomi Kazama          100.0%       18.9%      +11        MODERATE
# Joselyne Edwards vs Priscila Cachoeira   83.3%        67.3%      +28        MODERATE
# Uros Medic vs Gilbert Urbina             83.3%        67.3%      +27        MODERATE
# Gabriella Fernandes vs Julija Stoliarenko 83.3%        58.2%      +42        MODERATE
# Cody Brundage vs Eric McConico           100.0%       11.3%      +8         HIGH
#
# 💡 LEGEND:
#    CONSENSUS: % of models agreeing on winner
#    SPREAD: Difference between highest and lowest win probability
#    ELO DIFF: ELO rating difference (+ favors first fighter)
#    CONFIDENCE: Overall prediction reliability
