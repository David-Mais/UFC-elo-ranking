# %%
import pandas as pd

# Show first few rows of each table
unified = pd.read_csv("build/fights_unified.csv")
classified = pd.read_csv("build/fights_classified.csv")
elo_history = pd.read_csv("build/elo_history.csv")
elo_current = pd.read_csv("build/elo_ratings_current.csv")
elo_simple = pd.read_csv("build/elo_ratings_simple.csv")
profiles = pd.read_csv("build/fighter_profiles.csv")

print("Unified Fights Table:")
display(unified.head())
# Out:
# Unified Fights Table:
#          DATE               EVENT                                 BOUT  \
# 0  1994-03-11  UFC 2: No Way Out   Frank Hamaker  vs. Thaddeus Luster
# 1  1994-03-11  UFC 2: No Way Out       Jason DeLucia  vs. Scott Baker
# 2  1994-03-11  UFC 2: No Way Out     Johnny Rhodes  vs. David Levicki
# 3  1994-03-11  UFC 2: No Way Out       Johnny Rhodes  vs. Fred Ettish
# 4  1994-03-11  UFC 2: No Way Out   Orlando Wiet  vs. Robert Lucarelli
#
#   fighter_a_name    fighter_b_name winner_label       WEIGHTCLASS  \
# 0  Frank Hamaker   Thaddeus Luster            A  Open Weight Bout
# 1  Jason DeLucia       Scott Baker            A  Open Weight Bout
# 2  Johnny Rhodes     David Levicki            A  Open Weight Bout
# 3  Johnny Rhodes       Fred Ettish            A  Open Weight Bout
# 4   Orlando Wiet  Robert Lucarelli            A  Open Weight Bout
#
#         METHOD decision_type  ROUND   TIME    TIME FORMAT        REFEREE  \
# ...

# %%
print("Classified Fights Table:")
display(classified.head())
# Out:
# Classified Fights Table:
#          DATE               EVENT                                 BOUT  \
# 0  1994-03-11  UFC 2: No Way Out   Frank Hamaker  vs. Thaddeus Luster
# 1  1994-03-11  UFC 2: No Way Out       Jason DeLucia  vs. Scott Baker
# 2  1994-03-11  UFC 2: No Way Out     Johnny Rhodes  vs. David Levicki
# 3  1994-03-11  UFC 2: No Way Out       Johnny Rhodes  vs. Fred Ettish
# 4  1994-03-11  UFC 2: No Way Out   Orlando Wiet  vs. Robert Lucarelli
#
#   fighter_a_name    fighter_b_name winner_label       WEIGHTCLASS  \
# 0  Frank Hamaker   Thaddeus Luster            A  Open Weight Bout
# 1  Jason DeLucia       Scott Baker            A  Open Weight Bout
# 2  Johnny Rhodes     David Levicki            A  Open Weight Bout
# 3  Johnny Rhodes       Fred Ettish            A  Open Weight Bout
# 4   Orlando Wiet  Robert Lucarelli            A  Open Weight Bout
#
#         METHOD decision_type method_class  ...  judge_margins ROUND   TIME  \
# ...

# %%
print("Elo History Table:")
display(elo_history.head())
# Out:
# Elo History Table:
#          DATE              EVENT                               BOUT  \
# 0  1994-03-11  UFC 2: No Way Out  Frank Hamaker vs. Thaddeus Luster
# 1  1994-03-11  UFC 2: No Way Out      Jason DeLucia vs. Scott Baker
# 2  1994-03-11  UFC 2: No Way Out    Johnny Rhodes vs. David Levicki
# 3  1994-03-11  UFC 2: No Way Out      Johnny Rhodes vs. Fred Ettish
# 4  1994-03-11  UFC 2: No Way Out  Orlando Wiet vs. Robert Lucarelli
#
#                                         fighter_a_id  \
# 0  http://ufcstats.com/fighter-details/c3c23c9947...
# 1  http://ufcstats.com/fighter-details/6ceff86fae...
# 2  http://ufcstats.com/fighter-details/319fa1bd31...
# 3  http://ufcstats.com/fighter-details/319fa1bd31...
# 4  http://ufcstats.com/fighter-details/a6c2f5381d...
#
#                                         fighter_b_id fighter_a_name  \
# 0  http://ufcstats.com/fighter-details/505934897b...  Frank Hamaker
# 1  http://ufcstats.com/fighter-details/7d5b12de16...  Jason DeLucia
# ...

# %%
print("Current Elo Ratings Table:")
display(elo_current.head(10))
# Out:
# Current Elo Ratings Table:
#                                           fighter_id           fighter_name  \
# 0  http://ufcstats.com/fighter-details/07f72a2a75...              Jon Jones
# 1  http://ufcstats.com/fighter-details/6506c1d34d...      Georges St-Pierre
# 2  http://ufcstats.com/fighter-details/275aca31f6...        Islam Makhachev
# 3  http://ufcstats.com/fighter-details/150ff4cc64...           Max Holloway
# 4  http://ufcstats.com/fighter-details/f1b2aa7853...           Kamaru Usman
# 5  http://ufcstats.com/fighter-details/032cc3922d...    Khabib Nurmagomedov
# 6  http://ufcstats.com/fighter-details/e124894134...  Alexander Volkanovski
# 7  http://ufcstats.com/fighter-details/80fa8218c9...           Amanda Nunes
# 8  http://ufcstats.com/fighter-details/8d03ce87ca...        Francis Ngannou
# 9  http://ufcstats.com/fighter-details/c03520b5c8...      Merab Dvalishvili
#
#         rating  fights  wins  losses  draws  first_date   last_date
# ...

# %%
print("Simple Elo Ratings Table:")
display(elo_simple.head(10))
# Out:
# Simple Elo Ratings Table:
#             fighter_name       rating
# 0              Jon Jones  1738.435793
# 1      Georges St-Pierre  1710.009316
# 2        Islam Makhachev  1685.573623
# 3           Max Holloway  1676.828349
# 4           Kamaru Usman  1670.634206
# 5    Khabib Nurmagomedov  1666.583185
# 6  Alexander Volkanovski  1652.877752
# 7           Amanda Nunes  1652.839011
# 8        Francis Ngannou  1647.231858
# 9      Merab Dvalishvili  1646.728219
