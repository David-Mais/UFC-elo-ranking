# %%
'''
Overview
this notebook parses all fighters' details and tale of the tape

scrape ufc fighters' details
includes first, last, nickname, url
from url scrape scrape fighter's tale of the tape, 
includes fighter, height, weight, reach, stance, dob
'''
# Out:
# "\nOverview\nthis notebook parses all fighters' details and tale of the tape\n\nscrape ufc fighters' details\nincludes first, last, nickname, url\nfrom url scrape scrape fighter's tale of the tape, \nincludes fighter, height, weight, reach, stance, dob\n"

# %%
# imports
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm_notebook

# import library
import scrape_ufc_stats_library as LIB
import importlib
importlib.reload(LIB)

# import configs
import yaml
config = yaml.safe_load(open('scrape_ufc_stats_config.yaml'))

# %% [markdown]
# # Parse Fighter Details
# Includes:
# <br>
# First
# <br>
# Last
# <br>
# Nickname
# <br>
# URL

# %%
# generate list of urls for fighter details
list_of_alphabetical_urls = LIB.generate_alphabetical_urls()
print(list_of_alphabetical_urls)
# Out:
# ['http://ufcstats.com/statistics/fighters?char=a&page=all', 'http://ufcstats.com/statistics/fighters?char=b&page=all', 'http://ufcstats.com/statistics/fighters?char=c&page=all', 'http://ufcstats.com/statistics/fighters?char=d&page=all', 'http://ufcstats.com/statistics/fighters?char=e&page=all', 'http://ufcstats.com/statistics/fighters?char=f&page=all', 'http://ufcstats.com/statistics/fighters?char=g&page=all', 'http://ufcstats.com/statistics/fighters?char=h&page=all', 'http://ufcstats.com/statistics/fighters?char=i&page=all', 'http://ufcstats.com/statistics/fighters?char=j&page=all', 'http://ufcstats.com/statistics/fighters?char=k&page=all', 'http://ufcstats.com/statistics/fighters?char=l&page=all', 'http://ufcstats.com/statistics/fighters?char=m&page=all', 'http://ufcstats.com/statistics/fighters?char=n&page=all', 'http://ufcstats.com/statistics/fighters?char=o&page=all', 'http://ufcstats.com/statistics/fighters?char=p&page=all', 'http://ufcstats.com/statistics/fighters?char=q&page=
# ...

# %%
# create empty dataframe to store all fighter details
all_fighter_details_df = pd.DataFrame()
print(all_fighter_details_df)

# loop through list of alphabetical urls
for url in tqdm_notebook(list_of_alphabetical_urls):
    # get soup
    print(url)
    soup = LIB.get_soup(url)
    print("hello this is after soup")
    # parse fighter details
    fighter_details_df = LIB.parse_fighter_details(soup, config['fighter_details_column_names'])
    print(fighter_details_df)
    # concat fighter_details_df to all_fighter_details_df
    all_fighter_details_df = pd.concat([all_fighter_details_df, fighter_details_df])
    print(all_fighter_details_df)

# show all fighter details
display(all_fighter_details_df)

# write to file
all_fighter_details_df.to_csv(config['fighter_details_file_name'], index=False)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#   0%|          | 0/26 [00:00<?, ?it/s]
# http://ufcstats.com/statistics/fighters?char=a&page=all
# hello this is after soup
#        FIRST        LAST         NICKNAME  \
# 0        Tom       Aaron
# 1      Danny      Abbadi     The Assassin
# 2    Nariman     Abbasov        Bayraktar
# 3      David      Abbott             Tank
# 4      Hamdy  Abdelwahab       The Hammer
# ..       ...         ...              ...
# 222      Abu     Azaitar  Captain Morocco
# 223   Ottman     Azaitar        Bulldozer
# 224     Luiz     Azeredo
# 225  Luciano     Azevedo
# 226   Hunter       Azure
#
#                                                    URL
# 0    http://ufcstats.com/fighter-details/93fe7332d1...
# 1    http://ufcstats.com/fighter-details/15df64c02b...
# 2    http://ufcstats.com/fighter-details/59a9d6dac6...
# 3    http://ufcstats.com/fighter-details/b361180739...
# 4    http://ufcstats.com/fighter-details/3329d692ae...
# ...

# %%
# Add fighter id in ufc_fighter_details.csv
from pathlib import Path

csv_path = Path(config["fighter_details_file_name"])  # e.g., ../data/ufc_fighter_details.csv
df = pd.read_csv(csv_path)

df["FIGHTER_ID"] = (
    df["URL"].astype(str).str.strip().str.rstrip("/").str.split("/").str[-1]
)

cols = ["FIGHTER_ID"] + [c for c in df.columns if c != "FIGHTER_ID"]
df = df[cols]

df.to_csv(csv_path, index=False)

print(f"✅ Updated {csv_path} | rows: {len(df)}")
display(df.head(10))
# Out:
# ✅ Updated ../data/ufc_fighter_details.csv | rows: 4423
#          FIGHTER_ID     FIRST          LAST      NICKNAME  \
# 0  93fe7332d16c6ad9       Tom         Aaron           NaN
# 1  15df64c02b6b0fde     Danny        Abbadi  The Assassin
# 2  59a9d6dac61c2540   Nariman       Abbasov     Bayraktar
# 3  b361180739bed4b0     David        Abbott          Tank
# 4  3329d692aea4dc28     Hamdy    Abdelwahab    The Hammer
# 5  841695e02c99a521    Mansur   Abdul-Malik           NaN
# 6  2f5cbecbbe18bac4    Shamil  Abdurakhimov         Abrek
# 7  c0ed7b208197e8de  Hiroyuki           Abe       Abe Ani
# 8  5140122c3eecd307    Daichi           Abe           NaN
# 9  c9f6385af6df66d7      Papy         Abedi       Makambo
#
#                                                  URL
# 0  http://ufcstats.com/fighter-details/93fe7332d1...
# 1  http://ufcstats.com/fighter-details/15df64c02b...
# 2  http://ufcstats.com/fighter-details/59a9d6dac6...
# 3  http://ufcstats.com/fighter-details/b361180739...
# ...

# %% [markdown]
# # Parse Fighter Tale of the Tape
#
# Includes:
# <br>
# Fighter
# <br>
# Height
# <br>
# Weight
# <br>
# Reach
# <br>
# Stance
# <br>
# DOB
# <br>
# URL

# %%
# define list of urls of fighters to parse
list_of_fighter_urls = list(all_fighter_details_df['URL'])

# %% [markdown]
# ## Optional clean scrape
# only run this if you want to clear out the existing tott csv file and start from scratch

# %%
# File paths
tott_path = Path(config["fighter_tott_file_name"])
ckpt_path = Path("processed_fighter_tott.ckpt")

# Make sure folders exist
tott_path.parent.mkdir(parents=True, exist_ok=True)
tott_path.parent.mkdir(parents=True, exist_ok=True)

# Reset CSVs to header-only
pd.DataFrame(columns=config["fighter_tott_column_names"]).to_csv(tott_path, index=False)

# Remove checkpoint
ckpt_path.unlink(missing_ok=True)

print(f"✅ Cleared (header only): {tott_path}")
print(f"✅ Deleted checkpoint (if existed): {ckpt_path}")
# Out:
# ✅ Cleared (header only): ../data/ufc_fighter_tott.csv
# ✅ Deleted checkpoint (if existed): processed_fighter_tott.ckpt

# %%
import time
from tqdm.notebook import tqdm as tqdm_notebook

# ---------- I/O paths ----------
tott_path = Path(config["fighter_tott_file_name"])                # e.g. ../data/ufc_fighter_tott.csv
ckpt_path = Path("processed_fighter_tott.ckpt")    # checkpoint file

# ---------- source URLs ----------
try:
    list_of_fighter_urls  # already defined elsewhere
    src_urls = list_of_fighter_urls
except NameError:
    # fallback: read from fighter details CSV
    details_path = Path(config["fighter_details_file_name"])
    df_urls = pd.read_csv(details_path, usecols=["URL"])
    src_urls = df_urls["URL"].dropna().astype(str).unique().tolist()

# ---------- checkpoint + already-scraped ----------
done = set()
if ckpt_path.exists():
    done.update(u.strip() for u in ckpt_path.read_text().splitlines() if u.strip())

# (Optional) also skip any URLs already present in output CSV
if tott_path.exists() and tott_path.stat().st_size > 0:
    try:
        out_urls = pd.read_csv(tott_path, usecols=["URL"], dtype=str)["URL"].dropna().unique().tolist()
        done.update(out_urls)
    except Exception:
        pass

# Build todo list
todo = [u for u in src_urls if u not in done]

# For a quick test, limit how many to process this run (0 = no limit)
LIMIT = 0  # e.g. set to 50 for a small batch
if LIMIT > 0:
    todo = todo[:LIMIT]

print(f"Total fighter URLs: {len(src_urls)} | already done: {len(done)} | to do now: {len(todo)}")

# ---------- helpers ----------
def append_csv(df: pd.DataFrame, path: Path, columns: list):
    """Append rows to CSV with consistent column order; write header if new."""
    if df is None or df.empty:
        return
    path.parent.mkdir(parents=True, exist_ok=True)
    write_header = (not path.exists()) or path.stat().st_size == 0
    df.reindex(columns=columns).to_csv(path, mode="a", header=write_header, index=False)

fail_log = []

# ---------- run ----------
pbar = tqdm_notebook(total=len(todo))
for url in todo:
    try:
        soup = LIB.get_soup(url)  # your (now) robust get_soup
        parsed = LIB.parse_fighter_tott(soup)
        one_df = LIB.organise_fighter_tott(parsed, config["fighter_tott_column_names"], url)

        # persist immediately
        append_csv(one_df, tott_path, config["fighter_tott_column_names"])

        # checkpoint after successful write
        with open(ckpt_path, "a") as f:
            f.write(url + "\n")

        # polite delay
        time.sleep(0.3)
    except Exception as e:
        print(f"⚠️ Failed {url} -> {e}")
        fail_log.append({"URL": url, "ERROR": str(e)})
        time.sleep(0.8)
    finally:
        pbar.update(1)
pbar.close()

# ---------- quick peek ----------
if tott_path.exists() and tott_path.stat().st_size > 0:
    peek = pd.read_csv(tott_path)
    print(f"✅ Current Tale-of-the-Tape rows: {len(peek)}")
    display(peek.tail(10))
# Out:
# Total fighter URLs: 4423 | already done: 359 | to do now: 4064
#   0%|          | 0/4064 [00:00<?, ?it/s]
# ✅ Current Tale-of-the-Tape rows: 4423
#               FIGHTER HEIGHT    WEIGHT REACH    STANCE           DOB  \
# 4413      James Zikic  6' 2"  205 lbs.    --  Orthodox  Mar 01, 1977
# 4414  Errol Zimmerman  6' 3"  185 lbs.    --  Orthodox  Apr 20, 1986
# 4415      Cat Zingano  5' 6"  145 lbs.   68"  Southpaw  Jul 01, 1982
# 4416    Igor Zinoviev  6' 1"  199 lbs.    --  Orthodox            --
# 4417    Dave Zitanick     --  170 lbs.    --       NaN  Mar 05, 1980
# 4418      Alex Zuniga     --  145 lbs.    --       NaN            --
# 4419    George Zuniga  5' 9"  185 lbs.    --       NaN            --
# 4420     Allan Zuniga  5' 7"  155 lbs.   70"  Orthodox  Apr 04, 1992
# 4421  Brahyan Zurcher     --  145 lbs.    --       NaN  Mar 10, 1996
# 4422   Virgil Zwicker  6' 2"  205 lbs.   74"       NaN  Jun 26, 1982
#
#                                                     URL
# ...

# %%
# Path from your YAML config
tott_path = Path(config["fighter_tott_file_name"])  # e.g., ../data/ufc_fighter_tott.csv

# Load (as strings to avoid dtype issues)
df = pd.read_csv(tott_path, dtype=str)

# If a fight id column already exists with weird casing, normalize it first
for c in list(df.columns):
    if c.lower() == "fighter_id" and c != "FIGHTER_ID":
        df = df.rename(columns={c: "FIGHTER_ID"})
        break

# (Re)create FIGHTER_ID from the last segment of URL
df["FIGHTER_ID"] = (
    df["URL"].astype(str).str.strip().str.rstrip("/").str.split("/").str[-1]
)

# Reorder: FIGHTER_ID first
df = df[["FIGHTER_ID"] + [c for c in df.columns if c != "FIGHTER_ID"]]

# Save back
df.to_csv(tott_path, index=False)

print(f"✅ Added FIGHTER_ID to {tott_path} | rows: {len(df)}")
display(df.head(10))
# Out:
# ✅ Added FIGHTER_ID to ../data/ufc_fighter_tott.csv | rows: 4423
#          FIGHTER_ID              FIGHTER  HEIGHT    WEIGHT REACH    STANCE  \
# 0  93fe7332d16c6ad9            Tom Aaron      --  155 lbs.    --       NaN
# 1  15df64c02b6b0fde         Danny Abbadi  5' 11"  155 lbs.    --  Orthodox
# 2  59a9d6dac61c2540      Nariman Abbasov   5' 8"  155 lbs.   66"  Orthodox
# 3  b361180739bed4b0         David Abbott   6' 0"  265 lbs.    --    Switch
# 4  3329d692aea4dc28     Hamdy Abdelwahab   6' 2"  264 lbs.   72"  Southpaw
# 5  841695e02c99a521   Mansur Abdul-Malik   6' 2"  185 lbs.   80"  Orthodox
# 6  2f5cbecbbe18bac4  Shamil Abdurakhimov   6' 3"  235 lbs.   76"  Orthodox
# 7  c0ed7b208197e8de         Hiroyuki Abe   5' 6"  145 lbs.    --  Orthodox
# 8  5140122c3eecd307           Daichi Abe  5' 11"  170 lbs.   71"  Orthodox
# 9  c9f6385af6df66d7           Papy Abedi  5' 11"  185 lbs.    --  Southpaw
#
#             DOB                                                URL
# ...
