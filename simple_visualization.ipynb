# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your classified fights CSV
df = pd.read_csv("build/fights_classified.csv")

# Example 1: Count of fights per year
df['DATE'] = pd.to_datetime(df['DATE'])
df['year'] = df['DATE'].dt.year
fights_per_year = df.groupby('year').size()

plt.figure(figsize=(10,5))
fights_per_year.plot(kind='bar')
plt.title('Number of UFC Fights per Year')
plt.xlabel('Year')
plt.ylabel('Number of Fights')
plt.tight_layout()
plt.show()

# %%
# Example 2: Distribution of method_class
df['method_class'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(6,6))
plt.title('Distribution of Fight Outcomes')
plt.ylabel('')
plt.show()

# %%
# Only look at finishes
finishes = df[df['METHOD'].str.contains('KO|TKO|Submission', case=False, na=False)]
finish_types = finishes['METHOD'].str.extract('(KO|TKO|Submission)', expand=False).str.upper().value_counts()

finish_types.plot(kind='pie', autopct='%1.1f%%', figsize=(6,6))
plt.title('KO/TKO vs. Submission Finishes')
plt.ylabel('')
plt.show()

# %%
finish_rate = df.groupby('year')['method_class'].apply(lambda x: (x == 'finish').mean())

plt.figure(figsize=(10,5))
finish_rate.plot()
plt.title('Finish Rate by Year')
plt.xlabel('Year')
plt.ylabel('Finish Rate')
plt.ylim(0, 1)
plt.tight_layout()
plt.show()

# %%
# Define a finish as KO/TKO/Submission
# Create a finish column
df['is_finish'] = df['METHOD'].str.contains('KO|TKO|Submission', case=False, na=False)

# Then group by weight class and calculate mean
finish_rate = df.groupby('WEIGHTCLASS')['is_finish'].mean().sort_values(ascending=False)

finish_rate.plot(kind='bar', figsize=(12,5))
plt.title('Finish Rate by Weight Class')
plt.xlabel('Weight Class')
plt.ylabel('Finish Rate')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/t0/ksd3n8r93m173jn2fpp4z7x00000gn/T/ipykernel_32088/1947993654.py:12: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
# Out:
# Requirement already satisfied: pandas>=2.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.12/site-packages (from pandas>=2.0->-r requirements.txt (line 1)) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas>=2.0->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas>=2.0->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas>=2.0->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.0->-r requirements.txt (line 1)) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
